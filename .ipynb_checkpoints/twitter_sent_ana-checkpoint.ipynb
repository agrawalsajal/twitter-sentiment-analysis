# %%
import tweepy
import re
import pickle
import matplotlib.pyplot as plt
from tweepy import OAuthHandler

# %%
consumer_key = '8NDOZFf546jCU74zdQsldgVPA'
consumer_secret = 'xngNqg4fpEPvKebGsfCwadGb0l7G25ao2vwPxvMO6ppAHzt4HM' 
access_token = '3195178994-9XP6Y3GnG6fCIUcz3585m1oB3muxWvCP3BqIiPT'
access_secret ='9oD75Zx6L2RjTU4NmF2Lt8gIOCBJsP5dMnHEVjzrcV5Oe'

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
args = ['modi'];
api = tweepy.API(auth,timeout=10)

# %%
list_tweets = []

query = args[0]
if len(args) == 1:
    for status in tweepy.Cursor(api.search,q=query+" -filter:retweets",lang='en',result_type='recent',geocode="22.1568,89.4332,500km").items(100):
        list_tweets.append(status.text)

# %%
with open('svcclassifier.pickle','rb') as f:
    classifier = pickle.load(f)
    
with open('TFIDF.pickle','rb') as f:
    tfidf = pickle.load(f)

# %%
total_pos = 0
total_neg = 0

# Preprocessing the tweets and predicting sentiment
for tweet in list_tweets:
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r"\W"," ",tweet)
    tweet = re.sub(r"\d"," ",tweet)
    tweet = re.sub(r"\s+[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+[a-z]$"," ",tweet)
    tweet = re.sub(r"^[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+"," ",tweet)
    sent = classifier.predict(tfidf.transform([tweet]).toarray())
    print(tweet,":",sent)
    if sent[0] == 1:
        total_pos += 1
    else:
        total_neg += 1
# Out:
#  vinodchavdabjp phindu narendramodi only modi : [0]
# to the bhartiya mr narendra modi ji sir am mr chandan kumar rajak from sahibganj jharkhand want  : [0]
#  drpratiksha autumnrainwish arvindkejriwal don why people always tend to give attention to ones who only see  : [1]
#  amitshah let bjp speak to all sadhus to influence their respective followings to vote for modi in as per  : [0]
# it is been full day and wire scroll amp annie gowen have still not denounced this article as modi bjp rss right wi  : [1]
#  nice video related to pm modi speech ncc rally in new delhi : [1]
#  kuldeeppurohi renukajain what are the payment terms of janpath for making anti modi tweets  : [0]
# thanks to modi government national statistics commission no longer exist  : [1]
#  pubg_wala_he_kya pm modi tackles question on online game pubg via youtube : [1]
#  pmoindia very dynamic and strong pm narendra modi amp good motivator we nation proud of you  : [1]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
objects = ['Positive','Negative']
y_pos = np.arange(len(objects))

plt.bar(y_pos,[total_pos,total_neg],alpha=0.5)
plt.xticks(y_pos,objects)
plt.ylabel('Number')
plt.title('Number of Postive and NEgative Tweets')

plt.show()
